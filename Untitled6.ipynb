# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# !unzip "drive/MyDrive/S1Dataset.zip"
# Out:
# Archive:  drive/MyDrive/S1Dataset.zip
# replace S1_Dataset/Healthy group/1/1/emg.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# load data file
with open("/content/S1_Dataset/Healthy group/1/1/emg.csv") as f:
    lines = (line for line in f if not line.startswith('#'))
    _,time,data1,d2,d3,d4,d5,d6,d7,d8 = np.loadtxt("/content/S1_Dataset/Healthy group/1/1/emg.csv", delimiter=',', unpack=True, skiprows=1)

freq = 1/np.mean(np.diff(time))
print(time)
print(freq)
fig, (ax,ax2,ax3,ax4,ax5,ax6,ax7,ax8) = plt.subplots(8, 1, figsize=(25, 15))
ax.plot(time, data1, 'b')

ax2.plot(time, d2, 'b')
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('EMG amplitude [V]', fontsize=12)
ax.set_xlim(time[0], time[-1])
ax.set_title('Raw data', fontsize=16)

ax2.set_xlabel('Time [s]', fontsize=12)
ax2.set_ylabel('EMG amplitude [V]', fontsize=12)
ax2.set_xlim(time[0], time[-1])
ax2.set_title('Raw data', fontsize=16)

ax3.plot(time, d3, 'b')
ax3.set_xlabel('Time [s]', fontsize=12)
ax3.set_ylabel('EMG amplitude [V]', fontsize=12)
ax3.set_xlim(time[0], time[-1])
ax3.set_title('Raw data', fontsize=16)

ax4.plot(time, d4, 'b')
ax4.set_xlabel('Time [s]', fontsize=12)
ax4.set_ylabel('EMG amplitude [V]', fontsize=12)
ax4.set_xlim(time[0], time[-1])
ax4.set_title('Raw data', fontsize=16)
plt.locator_params(axis = 'both', nbins = 4)

ax5.plot(time, d5, 'b')
ax5.set_xlabel('Time [s]', fontsize=12)
ax5.set_ylabel('EMG amplitude [V]', fontsize=12)
ax5.set_xlim(time[0], time[-1])
ax5.set_title('Raw data', fontsize=16)
plt.locator_params(axis = 'both', nbins = 4)

ax6.plot(time, d6, 'b')
ax6.set_xlabel('Time [s]', fontsize=12)
ax6.set_ylabel('EMG amplitude [V]', fontsize=12)
ax6.set_xlim(time[0], time[-1])
ax6.set_title('Raw data', fontsize=16)
plt.locator_params(axis = 'both', nbins = 4)

ax7.plot(time, d7, 'b')
ax7.set_xlabel('Time [s]', fontsize=12)
ax7.set_ylabel('EMG amplitude [V]', fontsize=12)
ax7.set_xlim(time[0], time[-1])
ax7.set_title('Raw data', fontsize=16)
plt.locator_params(axis = 'both', nbins = 4)

ax8.plot(time, d8, 'b')
ax8.set_xlabel('Time [s]', fontsize=12)
ax8.set_ylabel('EMG amplitude [V]', fontsize=12)
ax8.set_xlim(time[0], time[-1])
ax8.set_title('Raw data', fontsize=16)
plt.locator_params(axis = 'both', nbins = 4)

plt.tight_layout()
# Out:
# [0.000e+00 1.000e-03 2.000e-03 ... 7.829e+00 7.830e+00 7.831e+00]
# 1000.0

# %%
from scipy.signal import butter, filtfilt
b, a = butter(2, ([10, 450]/(freq/2)), btype = 'bandpass')
dataf = filtfilt(b, a, data1)
dataf2 = filtfilt(b, a, d2)
dataf3 = filtfilt(b, a, d3)
dataf4 = filtfilt(b, a, d4)
dataf5 = filtfilt(b, a, d5)
dataf6 = filtfilt(b, a, d6)
dataf7 = filtfilt(b, a, d7)
dataf8 = filtfilt(b, a, d8)

# %%
fig, (ax,ax2) = plt.subplots(2, 1, sharex = True, sharey = True, figsize = (20, 15))
ax.plot(time, data1, 'r')
ax.set_title('Raw data', fontsize=16)
ax.grid()
print(len(data1))
ax2.plot(time, dataf, 'b')
ax2.set_xlabel('Time [s]', fontsize=12)
ax2.set_xlim(time[0], time[-1])
ax2.set_title('Band-pass filter at [10 400] Hz', fontsize=16)
fig.text(0, 0.5, 'EMG amplitude [V]', ha='center', va='center',
         rotation='vertical', fontsize=12)
plt.locator_params(axis = 'both', nbins = 4)
ax2.grid()
plt.tight_layout()
# Out:
# 7832

# %%
######filter at 450
datafr = abs(dataf)
b, a = butter(2, (8/(freq/2)), btype = 'low')
datafrle = filtfilt(b, a, datafr)
fig, (ax1,ax2,ax3,ax4) = plt.subplots(4, 1, sharex = True, sharey = True, figsize = (8, 7))
ax1.plot(time, data1, 'r')
ax1.set_title('Raw data', fontsize=12)
ax1.set_xlim(time[0], time[-1])
ax1.grid()
ax2.plot(time, dataf, 'b')
ax2.set_title('Band-pass filter at [10 400] Hz', fontsize=12)
ax2.grid()
ax3.plot(time, datafr, 'b')
ax3.set_title('Band-pass filter at [10 400] Hz and rectification', fontsize=12)
ax3.grid()
ax4.plot(time, datafrle, 'b', linewidth=2)
ax4.set_xlabel('Time [s]', fontsize=12)
ax4.set_title('Band-pass filter at [10 400] Hz, rectification and low-pass filter at 8 Hz',
              fontsize=12)
fig.text(0, 0.5, 'EMG amplitude [V]', ha='center', va='center',
         rotation='vertical', fontsize=12)
plt.locator_params(axis = 'both', nbins = 4)
ax4.grid()
plt.tight_layout(h_pad=.1)

# %%
# plot data
fig, ax = plt.subplots(1, 1, figsize=(8, 3))
ax.plot(time, data1, 'r')
ax.plot(time, datafrle, 'b', linewidth=2)
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('EMG amplitude [V]', fontsize=12)
ax.set_title('Band-pass filter at [10 400] Hz, rectification and low-pass filter at 8 Hz',
          fontsize=12)
ax.set_xlim(time[0], time[-1])
plt.locator_params(axis = 'both', nbins = 4)
plt.grid()

# %%
def detect_onset(x, threshold=0, n_above=1, n_below=0,
                 threshold2=0, n_above2=1, show=True, ax=None):
  
    x = np.atleast_1d(x).astype('float64')
    # deal with NaN's (by definition, NaN's are not greater than threshold)
    x[np.isnan(x)] = -np.inf
    # indices of data greater than or equal to threshold
    inds = np.nonzero(x >= threshold)[0]
    if inds.size:
        # initial and final indexes of almost continuous data
        inds = np.vstack((inds[np.diff(np.hstack((-np.inf, inds))) > n_below+1], \
                          inds[np.diff(np.hstack((inds, np.inf))) > n_below+1])).T
        # indexes of almost continuous data longer than or equal to n_above
        inds = inds[inds[:, 1]-inds[:, 0] >= n_above-1, :]
        # minimum amplitude of n_above2 values in x to detect
        if threshold2 is not None and inds.size:
            idel = np.ones(inds.shape[0], dtype=bool)
            for i in range(inds.shape[0]):
                if np.count_nonzero(x[inds[i, 0]: inds[i, 1]+1] >= threshold2) < n_above2:
                    idel[i] = False
            inds = inds[idel, :]
    if not inds.size:
        inds = np.array([])  # standardize inds shape for output
    if show and x.size > 1:  # don't waste my time ploting one datum
        _plot(x, threshold, n_above, n_below, threshold2, n_above2, inds, ax)

    return inds


def _plot(x, threshold, n_above, n_below, threshold2, n_above2, inds, ax):
    """Plot results of the detect_onset function, see its help."""
    try:
        import matplotlib.pyplot as plt
    except ImportError:
        print('matplotlib is not available.')
    else:
        if ax is None:
            _, ax = plt.subplots(1, 1, figsize=(8, 4))

        if inds.size:
            for (indi, indf) in inds:
                if indi == indf:
                    ax.plot(indf, x[indf], 'ro', mec='r', ms=6)
                else:
                    ax.plot(range(indi, indf+1), x[indi:indf+1], 'r', lw=1)
                    ax.axvline(x=indi, color='b', lw=1, ls='--')
                ax.axvline(x=indf, color='b', lw=1, ls='--')
            inds = np.vstack((np.hstack((0, inds[:, 1])),
                              np.hstack((inds[:, 0], x.size-1)))).T
            for (indi, indf) in inds:
                ax.plot(range(indi, indf+1), x[indi:indf+1], 'k', lw=1)
        else:
            ax.plot(x, 'k', lw=1)
            ax.axhline(y=threshold, color='r', lw=1, ls='-')

        ax.set_xlim(-.02*x.size, x.size*1.02-1)
        ymin, ymax = x[np.isfinite(x)].min(), x[np.isfinite(x)].max()
        yrange = ymax - ymin if ymax > ymin else 1
        ax.set_ylim(ymin - 0.1*yrange, ymax + 0.1*yrange)
        ax.set_xlabel('Data #', fontsize=14)
        ax.set_ylabel('Amplitude', fontsize=14)
        if threshold2 is not None:
            text = 'threshold=%.3g, n_above=%d, n_below=%d, threshold2=%.3g, n_above2=%d'
        else:
            text = 'threshold=%.3g, n_above=%d, n_below=%d, threshold2=%r, n_above2=%d'            
        ax.set_title(text % (threshold, n_above, n_below, threshold2, n_above2))
        # plt.grid()
        plt.show()

# %%
def linear_envelope(x, freq, fc_bp, fc_lp=1):
    """Calculate the linear envelope of a signal.

    Parameters
    ----------
    x     : 1D array_like
            raw signal
    freq  : number
            sampling frequency
    fc_bp : list [fc_h, fc_l], optional
            cutoff frequencies for the band-pass filter (in Hz)
    fc_lp : number, optional
            cutoff frequency for the low-pass filter (in Hz)

    Returns
    -------
    x     : 1D array_like
            linear envelope of the signal

    Notes
    -----
    A 2nd-order Butterworth filter with zero lag is used for the filtering.  

    See this notebook [1]_.

    References
    ----------
    .. [1] https://github.com/demotu/BMC/blob/master/notebooks/Electromyography.ipynb

    """
    
    import numpy as np
    from scipy.signal import butter, filtfilt
    
    if np.size(fc_bp) == 2:
        # band-pass filter
        x = abs(x)
        b, a = butter(2, (fc_bp/(freq/2.)), btype = 'bandpass')
        x = filtfilt(b, a, x)   
    if np.size(fc_lp) == 1:
        # full-wave rectification
        x = abs(x)
        # low-pass Butterworth filter
        b, a = butter(2, (fc_lp/(freq/2.)), btype = 'low')
        x = filtfilt(b, a, x)
    
    return x

# %%
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
data1p= linear_envelope(data1, freq, fc_bp=[10, 400])
threshold=6
inds = detect_onset(data1p, threshold=threshold,
                    n_above=1, n_below=0, show=True)
print(inds)
T1=[0]
for i in range(5):
  T1.append(np.argmin(data1p[inds[i,0]:inds[i+1,0]])+inds[i,0])
print(T1)
# Out:
# [[ 649 1568]
#  [2062 2601]
#  [3133 3758]
#  [4324 4722]
#  [5496 6714]
#  [7435 7831]]
# [0, 1816, 2884, 4037, 5115, 7122]

# %%
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
# %matplotlib inline
data2p= linear_envelope(d2, freq, fc_bp=[10, 400])
threshold=30
print(threshold)
inds = detect_onset(data2p, threshold=threshold,
                    n_above=1, n_below=0, show=True)
print(inds)
P=0
T2=[0]
for i in range(7):
  c=np.argmin(data2p[i*1000+200:(i+1)*1000])+i*1000+200
  if (c-P)>800:
    print(c)
    T2.append(c)
  P=c
print(T2)
# Out:
# 30
# [[ 764 1620]
#  [2054 2665]
#  [2912 3536]
#  [5479 6156]]
# 1787
# 2787
# 3822
# 4828
# 6867
# [0, 1787, 2787, 3822, 4828, 6867]

# %%
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
data3p= linear_envelope(d3, freq, fc_bp=[10, 400])
threshold=10
print(threshold)
inds = detect_onset(data3p, threshold=threshold,
                    n_above=1, n_below=0, show=True)
print(inds)
P=0
T3=[0]
for i in range(7):
  c=np.argmin(data3p[i*1000+200:(i+1)*1000])+i*1000+200
  if (c-P)>800:
    print(c)
    T3.append(c)
  P=c
print(T3)
# Out:
# 10
# [[1062 1762]
#  [2058 2671]
#  [2956 3767]
#  [4311 4640]
#  [5460 6318]]
# 1914
# 2792
# 3999
# 4999
# 6999
# [0, 1914, 2792, 3999, 4999, 6999]

# %%
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
data4p= linear_envelope(d4, freq, fc_bp=[10, 400])
threshold=10
print(threshold)
inds = detect_onset(data4p, threshold=threshold,
                    n_above=1, n_below=0, show=True)
print(inds)
P=0
T4=[0]
for i in range(6):
  c=np.argmin(data4p[i*1200+200:(i+1)*1200])+i*1200+200
  if (c-P)>800:
    print(c)
    T4.append(c)
  P=c
T4=T4[:-1]
print('l',c)
T4.append(np.argmax(data4p[c:])+c)
print(T4)
# Out:
# 10
# [[1071 2015]
#  [2205 3086]
#  [3347 4220]
#  [4400 5305]
#  [5654 6821]]
# 2108
# 3216
# 4306
# 5465
# 7199
# l 7199
# [0, 2108, 3216, 4306, 5465, 7199]

# %%
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
data5p= linear_envelope(d5, freq, fc_bp=[10, 400])
threshold=10
print(threshold)
inds = detect_onset(data5p, threshold=threshold,
                    n_above=1, n_below=0, show=True)
print(inds)
P=0
T5=[0]
for i in range(6):
  c=np.argmin(data5p[i*1200+200:(i+1)*1200])+i*1200+200
  if ((c-P)>800):
    print(c)
    T5.append(c)
  P=c
T5=T5[:-1]
T5.append(np.argmax(data5p[c:])+c)
print(T5)
# Out:
# 10
# [[1292 1735]
#  [2721 3159]
#  [5954 6166]]
# 2227
# 3523
# 4498
# 5518
# 7199
# [0, 2227, 3523, 4498, 5518, 7199]

# %%
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
data6p= linear_envelope(d6, freq, fc_bp=[10, 400])
threshold=30
print(threshold)
inds = detect_onset(data6p, threshold=threshold,
                    n_above=1, n_below=0, show=True)
print(inds)
print(np.std(data6p))
P=0
T6=[0]
for i in range(7):
  
  c=np.argmin(data6p[i*1000+200:(i+1)*1000])+i*1000+200
  max=np.max(data6p[P:c])
  print(max)
  if (max-data6p[c]>np.std(data6p)):
    print(c)
    T6.append(c)
  
  P=c
T6=T6[:-1]
T6.append(np.argmax(data6p[c:])+c)
print(T6)
# Out:
# 30
# [[1513 2223]
#  [2441 3292]
#  [3635 4299]
#  [5960 6560]]
# 13.47009597804515
# 3.4671112709443124
# 25.552673612221007
# 55.02212399383061
# 2327
# 58.56686349747483
# 3442
# 49.66395715290003
# 4524
# 28.277178064767185
# 5449
# 37.60455952166638
# 6999
# [0, 2327, 3442, 4524, 5449, 7757]

# %%
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
data7p= linear_envelope(d7, freq, fc_bp=[10, 400])
threshold=10
print(threshold)
inds = detect_onset(data7p, threshold=threshold,
                    n_above=1, n_below=0, show=True)
print(inds)
print(np.std(data7p))
P=0
T7=[0]
for i in range(7): 
  c=np.argmin(data7p[i*1000+200:(i+1)*1000])+i*1000+200
  max=np.max(data7p[P:c])
  print(max)
  if (max-data7p[c]>np.std(data7p)):
    print(c)
    T7.append(c)
  P=c
print(T7)
print(c)
T7.append(np.argmax(data7p[c:])+c)
print(T7)
# Out:
# 10
# [[1533 2319]
#  [2603 2995]
#  [3788 4095]
#  [4919 5272]]
# 3.9442770018244984
# 2.810379192146571
# 2.7735454288137196
# 17.05731329905947
# 2459
# 13.153933926476832
# 3398
# 12.148417023178897
# 4475
# 11.91585826557857
# 5669
# 6.799453492221473
# [0, 2459, 3398, 4475, 5669]
# 6764
# [0, 2459, 3398, 4475, 5669, 7142]

# %%
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
data8p= linear_envelope(d8, freq, fc_bp=[10, 400])
threshold=15
print(threshold)
inds = detect_onset(data8p, threshold=threshold,
                    n_above=1, n_below=0, show=True)
print(inds)
print(np.std(data8p))
P=0
T8=[0]
for i in range(6):
  
  c=np.argmin(data8p[i*1000+100:(i+1)*1000])+i*1000+100
  max=np.max(data8p[P:c])
  print(c)
  if (max-data8p[c]>np.std(data8p)):
    print(c)
    T8.append(c)
  P=c
print(c)
T8.append(np.argmax(data8p[c+1000:])+c+1000)
print(T8)
# Out:
# 15
# [[1714 2583]
#  [2822 3586]
#  [3967 4611]
#  [4897 5724]]
# 11.940438001429781
# 650
# 1326
# 2695
# 2695
# 3758
# 3758
# 4759
# 4759
# 5999
# 5999
# 5999
# [0, 2695, 3758, 4759, 5999, 7185]

# %%
print(T1)
print(T2)
print(T3)
print(T4)
print("left")
print(T5)
print(T6)
print(T7)
print(T8)
# Out:
# [0, 1816, 2884, 4037, 5115, 7122]
# [0, 1787, 2787, 3822, 4828, 6867]
# [0, 1914, 2792, 3999, 4999, 6999]
# [0, 2108, 3216, 4306, 5465, 7199]
# left
# [0, 2227, 3523, 4498, 5518, 7199]
# [0, 2327, 3442, 4524, 5449, 7757]
# [0, 2459, 3398, 4475, 5669, 7142]
# [0, 2695, 3758, 4759, 5999, 7185]

# %%
E1=[]
for i in range(len(T1)-1):
  E1.append((data1p[T1[i]:T1[i+1]]))

E2=[]
for i in range(len(T2)-1):
  E2.append((data2p[T2[i]:T2[i+1]]))

E3=[]
for i in range(len(T3)-1):
  E3.append((data3p[T3[i]:T3[i+1]]))

E4=[]
for i in range(len(T4)-1):
  E4.append((data4p[T4[i]:T4[i+1]]))

E5=[]
for i in range(len(T5)-1):
  E5.append((data5p[T5[i]:T5[i+1]]))

E6=[]
for i in range(len(T6)-1):
  E6.append((data6p[T6[i]:T6[i+1]]))

E7=[]
for i in range(len(T7)-1):
  E7.append((data7p[T8[i]:T8[i+1]]))

E8=[]
for i in range(len(T8)-1):
  E8.append((data8p[T8[i]:T8[i+1]]))

# %%
print(E1)
print(E2)
print(E3)
print(E4)
# Out:
# [array([1.8862711 , 1.89223342, 1.89817364, ..., 4.54923498, 4.54908045,
#        4.54897918]), array([4.54893112, 4.54893623, 4.54899445, ..., 4.09033981, 4.09020217,
#        4.09012606]), array([4.09011155, 4.0901587 , 4.09026756, ..., 4.05239094, 4.05227989,
#        4.05221214]), array([4.05218779, 4.05220693, 4.05226965, ..., 2.46185127, 2.46172034,
#        2.46163824]), array([2.46160499, 2.46162061, 2.46168514, ..., 3.73813369, 3.73801447,
#        3.73794151])]
# [array([ 2.17835239,  2.17818431,  2.17799135, ..., 25.47200433,
#        25.47132213, 25.47089422]), array([25.47071838, 25.47079239, 25.47111399, 25.47168092, 25.47249087,
#        25.47354154, 25.47483059, 25.47635568, 25.47811445, 25.48010452,
#        25.48232353, 25.48476907, 25.48743877, 25.49033032, 25.49344149,
#        25.49677009, 25.50031395, 25.50407089, 25.50803873, 25.51221525,
#        25.51659822, 25.52118538, 25.5259745 , 25.53096335, 25.53614973,
# ...

# %%
def phase(DATA):
  IC=[]
  FF=[]
  MST=[]
  HO=[]
  TO=[]
  FC=[]
  TV=[]

  IC.append((DATA[0][0:int(len(DATA[0])*0.12)]))
  FF.append((DATA[0][int(len(DATA[0])*0.12):int(len(DATA[0])*0.3)]))
  MST.append((DATA[0][int(len(DATA[0])*0.3):int(len(DATA[0])*0.4)]))
  HO.append((DATA[0][int(len(DATA[0])*0.4):int(len(DATA[0])*0.6)]))
  TO.append((DATA[0][int(len(DATA[0])*0.6):int(len(DATA[0])*0.75)]))
  FC.append((DATA[0][int(len(DATA[0])*0.75):int(len(DATA[0])*0.85)]))
  TV.append((DATA[0][int(len(DATA[0])*0.85):]))

  IC.append((DATA[1][0:int(len(DATA[1])*0.12)]))
  FF.append((DATA[1][int(len(DATA[1])*0.12):int(len(DATA[1])*0.3)]))
  MST.append((DATA[1][int(len(DATA[1])*0.3):int(len(DATA[1])*0.4)]))
  HO.append((DATA[1][int(len(DATA[1])*0.4):int(len(DATA[1])*0.6)]))
  TO.append((DATA[1][int(len(DATA[1])*0.6):int(len(DATA[1])*0.75)]))
  FC.append((DATA[1][int(len(DATA[1])*0.75):int(len(DATA[1])*0.85)]))
  TV.append((DATA[1][int(len(DATA[1])*0.85):]))

  IC.append((DATA[2][0:int(len(DATA[2])*0.12)]))
  FF.append((DATA[2][int(len(DATA[2])*0.12):int(len(DATA[2])*0.3)]))
  MST.append((DATA[2][int(len(DATA[2])*0.3):int(len(DATA[2])*0.4)]))
  HO.append((DATA[2][int(len(DATA[2])*0.4):int(len(DATA[2])*0.6)]))
  TO.append((DATA[2][int(len(DATA[2])*0.6):int(len(DATA[2])*0.75)]))
  FC.append((DATA[2][int(len(DATA[2])*0.75):int(len(DATA[2])*0.85)]))
  TV.append((DATA[2][int(len(DATA[2])*0.85):]))

  IC.append((DATA[3][0:int(len(DATA[3])*0.12)]))
  FF.append((DATA[3][int(len(DATA[3])*0.12):int(len(DATA[3])*0.3)]))
  MST.append((DATA[3][int(len(DATA[3])*0.3):int(len(DATA[3])*0.4)]))
  HO.append((DATA[3][int(len(DATA[3])*0.4):int(len(DATA[3])*0.6)]))
  TO.append((DATA[3][int(len(DATA[3])*0.6):int(len(DATA[3])*0.75)]))
  FC.append((DATA[3][int(len(DATA[3])*0.75):int(len(DATA[3])*0.85)]))
  TV.append((DATA[3][int(len(DATA[3])*0.85):]))

  IC.append((DATA[4][0:int(len(DATA[4])*0.12)]))
  FF.append((DATA[4][int(len(DATA[4])*0.12):int(len(DATA[4])*0.3)]))
  MST.append((DATA[4][int(len(DATA[4])*0.3):int(len(DATA[4])*0.4)]))
  HO.append((DATA[4][int(len(DATA[4])*0.4):int(len(DATA[4])*0.6)]))
  TO.append((DATA[4][int(len(DATA[4])*0.6):int(len(DATA[4])*0.75)]))
  FC.append((DATA[4][int(len(DATA[4])*0.75):int(len(DATA[4])*0.85)]))
  TV.append((DATA[4][int(len(DATA[4])*0.85):]))
  return IC,FF,MST,HO,TO,FC,TV

# %%
import pandas as pd
IC,FF,MST,HO,TO,FC,TV=phase(E1)
data = {'FF':FF,
        'MST':MST,
        'HO':HO,
        'TO':TO,
        'FC':FC,
        'TV':TV,
        'Label':np.repeat(1,len(E1))}
  
# Create DataFrame
df = pd.DataFrame(data)
  
# Print the output.
df
#5 steps
# Out:
#                                                   FF  ... Label
# 0  [2.626686627197452, 2.628768610763942, 2.63085...  ...     1
# 1  [4.95008078288908, 4.956353363190117, 4.962676...  ...     1
# 2  [4.68036002316662, 4.688909447455702, 4.697521...  ...     1
# 3  [4.452847070581713, 4.459253576109664, 4.46571...  ...     1
# 4  [3.9448785804452333, 3.9573047751446464, 3.969...  ...     1
#
# [5 rows x 7 columns]

# %%
IC,FF,MST,HO,TO,FC,TV=phase(E5)
data = {'FF':FF,
        'MST':MST,
        'HO':HO,
        'TO':TO,
        'FC':FC,
        'TV':TV,
        'Label':np.repeat(1,len(E5))}
  
# Create DataFrame
df = pd.DataFrame(data)
  
# Print the output.
df
# Out:
#                                                   FF  ... Label
# 0  [2.0124336523970787, 2.013607221972086, 2.0147...  ...     1
# 1  [4.499091774246209, 4.507791657170387, 4.51653...  ...     1
# 2  [4.877496126402839, 4.885188052530078, 4.89293...  ...     1
# 3  [4.077352523029064, 4.081771643209494, 4.08622...  ...     1
# 4  [6.851771182451423, 6.861982149012873, 6.87224...  ...     1
#
# [5 rows x 7 columns]

# %%
data = {'RRFF':data1p,
        'RC':data2p,
        'RTA':data3p,
        'RG':data4p,
        'LRFF':data5p,
        'LC':data6p,
        'LTA':data7p,
        'LG':data8p,
        'Label':np.repeat(1,len(data1p))
        } 
# Create DataFrame
dft = pd.DataFrame(data)
(dft)
# Out:
#           RRFF         RC       RTA  ...       LTA        LG  Label
# 0     1.886271   2.178352  2.516894  ...  2.252441  6.328783      1
# 1     1.892233   2.178184  2.517662  ...  2.256680  6.321689      1
# 2     1.898174   2.177991  2.518410  ...  2.260905  6.314590      1
# 3     1.904091   2.177773  2.519136  ...  2.265116  6.307489      1
# 4     1.909986   2.177530  2.519841  ...  2.269314  6.300384      1
# ...        ...        ...       ...  ...       ...       ...    ...
# 7827  8.112276  11.150539  4.551003  ...  2.775677  5.123328      1
# 7828  8.112261  11.150356  4.550975  ...  2.775660  5.123296      1
# 7829  8.112248  11.150201  4.550952  ...  2.775645  5.123268      1
# 7830  8.112237  11.150072  4.550932  ...  2.775633  5.123245      1
# 7831  8.112227  11.149965  4.550916  ...  2.775623  5.123226      1
#
# [7832 rows x 9 columns]

# %%
with open("/content/S1_Dataset/Healthy group/1/2/emg.csv") as f:
    lines = (line for line in f if not line.startswith('#'))
    _,time2,data12,d22,d32,d42,d52,d62,d72,d82 = np.loadtxt("/content/S1_Dataset/Healthy group/1/1/emg.csv", delimiter=',', unpack=True, skiprows=1)
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
freq = 1/np.mean(np.diff(time))
data12p= linear_envelope(data12, freq, fc_bp=[10, 400])
data22p= linear_envelope(d22, freq, fc_bp=[10, 400])
data32p= linear_envelope(d32, freq, fc_bp=[10, 400])
data42p= linear_envelope(d42, freq, fc_bp=[10, 400])
data52p= linear_envelope(d52, freq, fc_bp=[10, 400])
data62p= linear_envelope(d62, freq, fc_bp=[10, 400])
data72p= linear_envelope(d72, freq, fc_bp=[10, 400])
data82p= linear_envelope(d82, freq, fc_bp=[10, 400])

data2 = {'RRFF':data12p,
        'RC':data22p,
        'RTA':data32p,
        'RG':data42p,
        'LRFF':data52p,
        'LC':data62p,
        'LTA':data72p,
        'LG':data82p,
        'Label':np.repeat(1,len(data12p))
        } 
# Create DataFrame
dft2 = pd.DataFrame(data2)
(dft2)
# Out:
#           RRFF         RC       RTA  ...       LTA        LG  Label
# 0     1.886271   2.178352  2.516894  ...  2.252441  6.328783      1
# 1     1.892233   2.178184  2.517662  ...  2.256680  6.321689      1
# 2     1.898174   2.177991  2.518410  ...  2.260905  6.314590      1
# 3     1.904091   2.177773  2.519136  ...  2.265116  6.307489      1
# 4     1.909986   2.177530  2.519841  ...  2.269314  6.300384      1
# ...        ...        ...       ...  ...       ...       ...    ...
# 7827  8.112276  11.150539  4.551003  ...  2.775677  5.123328      1
# 7828  8.112261  11.150356  4.550975  ...  2.775660  5.123296      1
# 7829  8.112248  11.150201  4.550952  ...  2.775645  5.123268      1
# 7830  8.112237  11.150072  4.550932  ...  2.775633  5.123245      1
# 7831  8.112227  11.149965  4.550916  ...  2.775623  5.123226      1
#
# [7832 rows x 9 columns]

# %%
with open("/content/S1_Dataset/Healthy group/1/3/emg.csv") as f:
    lines = (line for line in f if not line.startswith('#'))
    _,time3,data13,d23,d33,d43,d53,d63,d73,d83 = np.loadtxt("/content/S1_Dataset/Healthy group/1/3/emg.csv", delimiter=',', unpack=True, skiprows=1)
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
freq = 1/np.mean(np.diff(time))
data13p= linear_envelope(data13, freq, fc_bp=[10, 400])
data23p= linear_envelope(d23, freq, fc_bp=[10, 400])
data33p= linear_envelope(d33, freq, fc_bp=[10, 400])
data43p= linear_envelope(d43, freq, fc_bp=[10, 400])
data53p= linear_envelope(d53, freq, fc_bp=[10, 400])
data63p= linear_envelope(d63, freq, fc_bp=[10, 400])
data73p= linear_envelope(d73, freq, fc_bp=[10, 400])
data83p= linear_envelope(d83, freq, fc_bp=[10, 400])

data3 = {'RRFF':data13p,
        'RC':data23p,
        'RTA':data33p,
        'RG':data43p,
        'LRFF':data53p,
        'LC':data63p,
        'LTA':data73p,
        'LG':data83p,
        'Label':np.repeat(1,len(data13p))
        } 
# Create DataFrame
dft3 = pd.DataFrame(data3)
(dft3)
# Out:
#           RRFF         RC       RTA  ...       LTA         LG  Label
# 0    -1.855192   1.144056  1.850901  ...  2.952810  -3.774087      1
# 1    -1.829899   1.139942  1.855198  ...  2.950434  -3.735654      1
# 2    -1.804628   1.135814  1.859478  ...  2.948046  -3.697245      1
# 3    -1.779381   1.131674  1.863742  ...  2.945647  -3.658859      1
# 4    -1.754157   1.127521  1.867989  ...  2.943237  -3.620500      1
# ...        ...        ...       ...  ...       ...        ...    ...
# 8249  6.172619  21.681203  6.762831  ...  7.174531  11.795790      1
# 8250  6.172601  21.680998  6.762833  ...  7.174481  11.795680      1
# 8251  6.172585  21.680824  6.762834  ...  7.174439  11.795587      1
# 8252  6.172572  21.680679  6.762835  ...  7.174403  11.795508      1
# 8253  6.172561  21.680559  6.762836  ...  7.174374  11.795444      1
#
# [8254 rows x 9 columns]

# %%
with open("/content/S1_Dataset/Healthy group/1/4/emg.csv") as f:
    lines = (line for line in f if not line.startswith('#'))
    _,time4,data14,d24,d34,d44,d54,d64,d74,d84 = np.loadtxt("/content/S1_Dataset/Healthy group/1/4/emg.csv", delimiter=',', unpack=True, skiprows=1)
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
freq = 1/np.mean(np.diff(time4))
data14p= linear_envelope(data14, freq, fc_bp=[10, 400])
data24p= linear_envelope(d24, freq, fc_bp=[10, 400])
data34p= linear_envelope(d34, freq, fc_bp=[10, 400])
data44p= linear_envelope(d44, freq, fc_bp=[10, 400])
data54p= linear_envelope(d54, freq, fc_bp=[10, 400])
data64p= linear_envelope(d64, freq, fc_bp=[10, 400])
data74p= linear_envelope(d74, freq, fc_bp=[10, 400])
data84p= linear_envelope(d84, freq, fc_bp=[10, 400])

data4 = {'RRFF':data14p,
        'RC':data24p,
        'RTA':data34p,
        'RG':data44p,
        'LRFF':data54p,
        'LC':data64p,
        'LTA':data74p,
        'LG':data84p,
        'Label':np.repeat(1,len(data14p))
        } 
# Create DataFrame
dft4 = pd.DataFrame(data4)
(dft4)
# Out:
#           RRFF        RC       RTA  ...       LTA        LG  Label
# 0     2.565455 -1.196544  1.155583  ... -5.288749  4.994931      1
# 1     2.567947 -1.184689  1.160969  ... -5.252426  4.997821      1
# 2     2.570423 -1.172840  1.166337  ... -5.216127  5.000696      1
# 3     2.572882 -1.160996  1.171686  ... -5.179855  5.003558      1
# 4     2.575325 -1.149158  1.177017  ... -5.143611  5.006405      1
# ...        ...       ...       ...  ...       ...       ...    ...
# 8366  6.241937  5.049381  4.721352  ...  4.632889  5.461875      1
# 8367  6.241907  5.049373  4.721334  ...  4.632876  5.461854      1
# 8368  6.241882  5.049365  4.721319  ...  4.632864  5.461835      1
# 8369  6.241860  5.049359  4.721307  ...  4.632855  5.461819      1
# 8370  6.241843  5.049353  4.721296  ...  4.632847  5.461806      1
#
# [8371 rows x 9 columns]

# %%
with open("/content/S1_Dataset/Healthy group/1/5/emg.csv") as f:
    lines = (line for line in f if not line.startswith('#'))
    _,time5,data15,d25,d35,d45,d55,d65,d75,d85 = np.loadtxt("/content/S1_Dataset/Healthy group/1/5/emg.csv", delimiter=',', unpack=True, skiprows=1)
# rectus femoris, biceps femoris, tibialis anterior and gastrocnemius
freq = 1/np.mean(np.diff(time5))
data15p= linear_envelope(data15, freq, fc_bp=[10, 400])
data25p= linear_envelope(d25, freq, fc_bp=[10, 400])
data35p= linear_envelope(d35, freq, fc_bp=[10, 400])
data45p= linear_envelope(d45, freq, fc_bp=[10, 400])
data55p= linear_envelope(d55, freq, fc_bp=[10, 400])
data65p= linear_envelope(d65, freq, fc_bp=[10, 400])
data75p= linear_envelope(d75, freq, fc_bp=[10, 400])
data85p= linear_envelope(d85, freq, fc_bp=[10, 400])

data5 = {'RRFF':data15p,
        'RC':data25p,
        'RTA':data35p,
        'RG':data45p,
        'LRFF':data55p,
        'LC':data65p,
        'LTA':data75p,
        'LG':data85p,
        'Label':np.repeat(1,len(data15p))
        } 
# Create DataFrame
dft5 = pd.DataFrame(data5)
(dft5)
# Out:
#           RRFF         RC       RTA  ...       LTA         LG  Label
# 0     3.171109  -1.025624  0.350338  ...  1.917070   3.042904      1
# 1     3.167813  -1.016952  0.359836  ...  1.932012   3.056358      1
# 2     3.164504  -1.008266  0.369315  ...  1.946956   3.069807      1
# 3     3.161182  -0.999567  0.378774  ...  1.961901   3.083249      1
# 4     3.157847  -0.990854  0.388212  ...  1.976847   3.096685      1
# ...        ...        ...       ...  ...       ...        ...    ...
# 7626  6.191278  27.517598  5.960076  ...  7.455293  14.261008      1
# 7627  6.191263  27.517424  5.960077  ...  7.455240  14.260863      1
# 7628  6.191250  27.517276  5.960077  ...  7.455195  14.260740      1
# 7629  6.191239  27.517152  5.960077  ...  7.455156  14.260637      1
# 7630  6.191230  27.517050  5.960077  ...  7.455125  14.260552      1
#
# [7631 rows x 9 columns]

# %%
dft12=dft.append(dft2)
dftt123=dft12.append(dft3)
dftt1234=dftt123.append(dft4)
dftt12345=dftt1234.append(dft5)

# %%
dftt12345.iloc[:,0:4].shape
# Out:
# (39920, 4)

# %%
print(len(dftt1234))
train = dftt12345.iloc[:int(0.8*len(dftt12345))]
print(train)
x,Y=train.iloc[:,0:4],train.iloc[:,4:8]
test = dftt12345[int(0.8*len(dftt12345)):]
xt,yt=test.iloc[:,0:4],test.iloc[:,4:8]
print(x.shape,xt.shape)
# Out:
# 32289
#           RRFF        RC       RTA  ...       LTA        LG  Label
# 0     1.886271  2.178352  2.516894  ...  2.252441  6.328783      1
# 1     1.892233  2.178184  2.517662  ...  2.256680  6.321689      1
# 2     1.898174  2.177991  2.518410  ...  2.260905  6.314590      1
# 3     1.904091  2.177773  2.519136  ...  2.265116  6.307489      1
# 4     1.909986  2.177530  2.519841  ...  2.269314  6.300384      1
# ...        ...       ...       ...  ...       ...       ...    ...
# 8013  5.851786  3.612886  4.336736  ...  4.287230  5.445945      1
# 8014  5.854578  3.621541  4.338009  ...  4.290156  5.447582      1
# 8015  5.857367  3.630190  4.339294  ...  4.293073  5.449202      1
# 8016  5.860151  3.638835  4.340592  ...  4.295981  5.450806      1
# 8017  5.862932  3.647473  4.341904  ...  4.298878  5.452393      1
#
# [31936 rows x 9 columns]
# (31936, 4) (7984, 4)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
# Create linear regression object
regr = linear_model.LinearRegression()
# Train the model using the training sets
regr.fit(x, Y)
# Make predictions using the testing set
y_pred = regr.predict(xt)
# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(yt, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(yt, y_pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(yt, y_pred)))
# Plot outputs
plt.scatter(xt, yt, color="black",label='ground truth')
plt.scatter(xt,y_pred, color="blue",label='prediction')
plt.legend(loc="upper left")
plt.xticks(())
plt.yticks(())
plt.show()
# Out:
# Coefficients:
#  [[-0.47768602  0.12055652 -0.00468464  0.10537245]
#  [-1.04024435  0.24605188  0.54620046  0.37064541]
#  [-1.06783393  0.09715919  0.13011566  0.11044843]
#  [-3.14660329  0.14086437  2.50508935 -0.54619441]]
# Mean squared error: 25.25
# Coefficient of determination: 0.29
# RMSE 5.0247672235256085

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(8, 4))
P1, freqs1, t1, im1 = plt.specgram(dataf, NFFT=128, Fs=freq, noverlap = 64, cmap=plt.cm.jet)
# P: array of shape (len(times), len(freqs)) of power,
# freqs: array of frequencies, 
# bins: time points the spectrogram is calculated over,
# im: matplotlib.image.AxesImage instance
ax1.set_title('Short-Time Fourier Transform', fontsize=18)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Frequency [Hz]')
ax1.set_xlim(t1[0], t1[-1])
plt.tight_layout()
plt.show()

fig, ax1 = plt.subplots(1, 1, figsize=(8, 4))
P2, freqs22, t22, im2 = plt.specgram(dataf2, NFFT=128, Fs=freq, noverlap = 64, cmap=plt.cm.jet)
# P: array of shape (len(times), len(freqs)) of power,
# freqs: array of frequencies, 
# bins: time points the spectrogram is calculated over,
# im: matplotlib.image.AxesImage instance
ax1.set_title('Short-Time Fourier Transform', fontsize=18)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Frequency [Hz]')
ax1.set_xlim(t22[0], t22[-1])
plt.tight_layout()
plt.show()

fig, ax1 = plt.subplots(1, 1, figsize=(8, 4))
P3, freqs3, t3, im3 = plt.specgram(dataf3, NFFT=128, Fs=freq, noverlap = 64, cmap=plt.cm.jet)
# P: array of shape (len(times), len(freqs)) of power,
# freqs: array of frequencies, 
# bins: time points the spectrogram is calculated over,
# im: matplotlib.image.AxesImage instance
ax1.set_title('Short-Time Fourier Transform', fontsize=18)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Frequency [Hz]')
ax1.set_xlim(t3[0], t3[-1])
plt.tight_layout()

fig, ax1 = plt.subplots(1, 1, figsize=(8, 4))
P4, freqs4, t4, im4 = plt.specgram(dataf4, NFFT=128, Fs=freq, noverlap = 64, cmap=plt.cm.jet)
# P: array of shape (len(times), len(freqs)) of power,
# freqs: array of frequencies, 
# bins: time points the spectrogram is calculated over,
# im: matplotlib.image.AxesImage instance
ax1.set_title('Short-Time Fourier Transform', fontsize=18)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Frequency [Hz]')
ax1.set_xlim(t4[0], t4[-1])
plt.tight_layout()
plt.show()

fig, ax1 = plt.subplots(1, 1, figsize=(8, 4))
P5, freqs5, t5, im5 = plt.specgram(dataf5, NFFT=128, Fs=freq, noverlap = 64, cmap=plt.cm.jet)
# P: array of shape (len(times), len(freqs)) of power,
# freqs: array of frequencies, 
# bins: time points the spectrogram is calculated over,
# im: matplotlib.image.AxesImage instance
ax1.set_title('Short-Time Fourier Transform', fontsize=18)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Frequency [Hz]')
ax1.set_xlim(t5[0], t5[-1])
plt.tight_layout()
plt.show()

fig, ax1 = plt.subplots(1, 1, figsize=(8, 4))
P6, freqs6, t6, im6 = plt.specgram(dataf6, NFFT=128, Fs=freq, noverlap = 64, cmap=plt.cm.jet)
# P: array of shape (len(times), len(freqs)) of power,
# freqs: array of frequencies, 
# bins: time points the spectrogram is calculated over,
# im: matplotlib.image.AxesImage instance
ax1.set_title('Short-Time Fourier Transform', fontsize=18)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Frequency [Hz]')
ax1.set_xlim(t6[0], t6[-1])
plt.tight_layout()
plt.show()

fig, ax1 = plt.subplots(1, 1, figsize=(8, 4))
P7, freqs7, t7, im7 = plt.specgram(dataf7, NFFT=128, Fs=freq, noverlap = 64, cmap=plt.cm.jet)
# P: array of shape (len(times), len(freqs)) of power,
# freqs: array of frequencies, 
# bins: time points the spectrogram is calculated over,
# im: matplotlib.image.AxesImage instance
ax1.set_title('Short-Time Fourier Transform', fontsize=18)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Frequency [Hz]')
ax1.set_xlim(t7[0], t7[-1])
plt.tight_layout()

fig, ax1 = plt.subplots(1, 1, figsize=(8, 4))
P8, freqs8, t8, im8 = plt.specgram(dataf8, NFFT=128, Fs=freq, noverlap = 64, cmap=plt.cm.jet)
# P: array of shape (len(times), len(freqs)) of power,
# freqs: array of frequencies, 
# bins: time points the spectrogram is calculated over,
# im: matplotlib.image.AxesImage instance
ax1.set_title('Short-Time Fourier Transform', fontsize=18)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Frequency [Hz]')
ax1.set_xlim(t8[0], t8[-1])
plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

t2, freqs2 = np.meshgrid(t1, freqs1)

fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(t2, freqs2, P1, rstride=1, cstride=1, cmap=plt.cm.jet,
                       linewidth=0, antialiased=False)

ax.set_xlim(t1[0], t1[-1])
ax.set_ylim(0, 500)
ax.set_zlim(np.min(P1), np.max(P1))
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('Frequency [Hz]', fontsize=12)
ax.set_zlabel('Power', fontsize=12)
ax.set_title('Short-Time Fourier Transform', fontsize=16, y=1.04)
ax.view_init(30, 60)
plt.show()

t2, freqs2 = np.meshgrid(t22, freqs22)
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(t2, freqs2, P2, rstride=1, cstride=1, cmap=plt.cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlim(t22[0], t22[-1])
ax.set_ylim(0, 500)
ax.set_zlim(np.min(P2), np.max(P2))
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('Frequency [Hz]', fontsize=12)
ax.set_zlabel('Power', fontsize=12)
ax.set_title('Short-Time Fourier Transform', fontsize=16, y=1.04)
ax.view_init(30, 60)
plt.show()


t2, freqs2 = np.meshgrid(t3, freqs3)
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(t2, freqs2, P3, rstride=1, cstride=1, cmap=plt.cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlim(t3[0], t3[-1])
ax.set_ylim(0, 500)
ax.set_zlim(np.min(P2), np.max(P2))
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('Frequency [Hz]', fontsize=12)
ax.set_zlabel('Power', fontsize=12)
ax.set_title('Short-Time Fourier Transform', fontsize=16, y=1.04)
ax.view_init(30, 60)
plt.show()

t2, freqs2 = np.meshgrid(t4, freqs4)
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(t2, freqs2, P4, rstride=1, cstride=1, cmap=plt.cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlim(t4[0], t4[-1])
ax.set_ylim(0, 500)
ax.set_zlim(np.min(P2), np.max(P2))
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('Frequency [Hz]', fontsize=12)
ax.set_zlabel('Power', fontsize=12)
ax.set_title('Short-Time Fourier Transform', fontsize=16, y=1.04)
ax.view_init(30, 60)
plt.show()

t2, freqs2 = np.meshgrid(t5, freqs5)
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(t2, freqs2, P5, rstride=1, cstride=1, cmap=plt.cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlim(t5[0], t5[-1])
ax.set_ylim(0, 500)
ax.set_zlim(np.min(P2), np.max(P2))
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('Frequency [Hz]', fontsize=12)
ax.set_zlabel('Power', fontsize=12)
ax.set_title('Short-Time Fourier Transform', fontsize=16, y=1.04)
ax.view_init(30, 60)
plt.show()

t2, freqs2 = np.meshgrid(t6, freqs6)
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(t2, freqs2, P6, rstride=1, cstride=1, cmap=plt.cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlim(t6[0], t6[-1])
ax.set_ylim(0, 500)
ax.set_zlim(np.min(P2), np.max(P2))
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('Frequency [Hz]', fontsize=12)
ax.set_zlabel('Power', fontsize=12)
ax.set_title('Short-Time Fourier Transform', fontsize=16, y=1.04)
ax.view_init(30, 60)
plt.show()

t2, freqs2 = np.meshgrid(t7, freqs7)
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(t2, freqs2, P7, rstride=1, cstride=1, cmap=plt.cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlim(t7[0], t7[-1])
ax.set_ylim(0, 500)
ax.set_zlim(np.min(P2), np.max(P2))
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('Frequency [Hz]', fontsize=12)
ax.set_zlabel('Power', fontsize=12)
ax.set_title('Short-Time Fourier Transform', fontsize=16, y=1.04)
ax.view_init(30, 60)
plt.show()

t2, freqs2 = np.meshgrid(t8, freqs8)
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(t2, freqs2, P8, rstride=1, cstride=1, cmap=plt.cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlim(t8[0], t8[-1])
ax.set_ylim(0, 500)
ax.set_zlim(np.min(P2), np.max(P2))
ax.set_xlabel('Time [s]', fontsize=12)
ax.set_ylabel('Frequency [Hz]', fontsize=12)
ax.set_zlabel('Power', fontsize=12)
ax.set_title('Short-Time Fourier Transform', fontsize=16, y=1.04)
ax.view_init(30, 60)
plt.show()
